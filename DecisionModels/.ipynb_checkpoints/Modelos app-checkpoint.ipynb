# %% [markdown]
# https://repository.usc.edu.co/handle/20.500.12421/5080
# Trabajo de grado USC en gestión de proyectos Riesgos

# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup

d = {} 
numero=5080
#dataframe=None
datosrfinal = []
for count in range(0,10):
    URL='https://repository.usc.edu.co/handle/20.500.12421/'+str(numero)+'?show=full'
    estructura = requests.get(URL,verify=False).text
    contenido = BeautifulSoup(estructura, "lxml")
    #Lista para capturar los tr del documento html
    dastosr=[]

    for datos in contenido.find_all('tr'):
        validador=datos.text.replace('\n', '').strip()
        if validador.startswith('dc.contributor.advisor'):
            advisor=validador[22:]
        if validador.startswith('dc.subject.keyword'):
            dastosr.append(validador[18:])
        if validador.startswith('dc.subject'):
            l=validador[10:].replace('.keyword', '').strip()
            l=l.replace('es_ES', '').strip()
            dastosr.append(l)
        #se quitan duplicados de la lista
        for i in dastosr:
            if i not in datosrfinal:
                datosrfinal.append(i)
        #construcción de un diccionario para un dataframe del resultado final
        for i in datosrfinal:
            d[i] = advisor
numero+=1
dataframe=pd.Series(d).to_frame('Advisor').reset_index()
dataframe=dataframe.rename(columns={'index':'Keyword'})
dataframe = dataframe[["Advisor",'Keyword']]
# Out:
# C:\Users\HP\anaconda3\lib\site-packages\urllib3\connectionpool.py:979: InsecureRequestWarning: Unverified HTTPS request is being made to host 'repository.usc.edu.co'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# C:\Users\HP\anaconda3\lib\site-packages\urllib3\connectionpool.py:979: InsecureRequestWarning: Unverified HTTPS request is being made to host 'repository.usc.edu.co'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# C:\Users\HP\anaconda3\lib\site-packages\urllib3\connectionpool.py:979: InsecureRequestWarning: Unverified HTTPS request is being made to host 'repository.usc.edu.co'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# C:\Users\HP\anaconda3\lib\site-packages\urllib3\connectionpool.py:979: InsecureRequestWarning: Unverified HTTPS request is being made to host 'repository.usc.edu.co'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# C:\Users\HP\anaconda3\lib\site-packages\urllib3\connectionpool.py:979: InsecureRequestWarning: Unverified HTTPS request is being made to host 'repository.usc.edu.co'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# C:\Users\HP\anaconda3\lib\site-packages\urllib3\connectionpool.py:979: InsecureRequestWarning: Unverified HTTPS request is being made to host 'repository.usc.edu.co'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# C:\Users\HP\anaconda3\lib\site-packages\urllib3\connectionpool.py:979: InsecureRequestWarning: Unverified HTTPS request is being made to host 'repository.usc.edu.co'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# C:\Users\HP\anaconda3\lib\site-packages\urllib3\connectionpool.py:979: InsecureRequestWarning: Unverified HTTPS request is being made to host 'repository.usc.edu.co'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# C:\Users\HP\anaconda3\lib\site-packages\urllib3\connectionpool.py:979: InsecureRequestWarning: Unverified HTTPS request is being made to host 'repository.usc.edu.co'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# C:\Users\HP\anaconda3\lib\site-packages\urllib3\connectionpool.py:979: InsecureRequestWarning: Unverified HTTPS request is being made to host 'repository.usc.edu.co'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(

# %%
dataframe
# Out:
#                         Advisor                             Keyword
# 0  Salazar Ramos, Andrés Felipe  Simulación Y Estimación Del Tiempo
# 1  Salazar Ramos, Andrés Felipe     Lanzamiento De Nuevos Productos
# 2  Salazar Ramos, Andrés Felipe                       Incertidumbre
# 3  Salazar Ramos, Andrés Felipe               Gerencia De Proyectos
# 4  Salazar Ramos, Andrés Felipe    Simulation And Time Modification
# 5  Salazar Ramos, Andrés Felipe              Launch Of New Products
# 6  Salazar Ramos, Andrés Felipe                         Uncertainty
# 7  Salazar Ramos, Andrés Felipe                  Project Management

# %%
dastosr
# Out:
# ['Simulación Y Estimación Del Tiempo',
#  'Lanzamiento De Nuevos Productos',
#  'Incertidumbre',
#  'Gerencia De Proyectos',
#  'Simulation And Time Modification',
#  'Simulation And Time Modification',
#  'Launch Of New Products',
#  'Launch Of New Products',
#  'Uncertainty',
#  'Uncertainty',
#  'Project Management',
#  'Project Management']

# %%
datosrfinal
# Out:
# ['Simulación Y Estimación Del Tiempo',
#  'Lanzamiento De Nuevos Productos',
#  'Incertidumbre',
#  'Gerencia De Proyectos',
#  'Simulation And Time Modification',
#  'Launch Of New Products',
#  'Uncertainty',
#  'Project Management']

# %%
advisor
# Out:
# 'Salazar Ramos, Andrés Felipe'

# %%
'''
        advisor=dastosr[0].replace('dc.contributor.advisor', '').strip()
        #No es posible encontrar el programa según un orden establecido
        #programa=dastosr[-2]

        datostextoesp=[]
        for valoresp in dastosr:
                if valoresp.startswith('dc.subject'):
                    datostextoesp.append(valoresp[10:])

        datostextoesp_=[]
        for valoresp_ in datostextoesp:
                if not valoresp_.startswith('.keyword'):
                    datostextoesp_.append(valoresp_.replace('es_ES', '').strip())

        #construcción de un diccionario
        resultados = datostextoesp_
        count = advisor

        for i in resultados:
            d[i] = advisor

        dataframe=pd.Series(d).to_frame('Advisor').reset_index()
        dataframe=dataframe.rename(columns={'index':'Keyword'})

        dataframe = dataframe[["Advisor",'Keyword']]
    except:
            pass
    numero+=1
    
print(dataframe)
'''
# Out:
# '\n        advisor=dastosr[0].replace(\'dc.contributor.advisor\', \'\').strip()\n        #No es posible encontrar el programa según un orden establecido\n        #programa=dastosr[-2]\n\n        datostextoesp=[]\n        for valoresp in dastosr:\n                if valoresp.startswith(\'dc.subject\'):\n                    datostextoesp.append(valoresp[10:])\n\n        datostextoesp_=[]\n        for valoresp_ in datostextoesp:\n                if not valoresp_.startswith(\'.keyword\'):\n                    datostextoesp_.append(valoresp_.replace(\'es_ES\', \'\').strip())\n\n        #construcción de un diccionario\n        resultados = datostextoesp_\n        count = advisor\n\n        for i in resultados:\n            d[i] = advisor\n\n        dataframe=pd.Series(d).to_frame(\'Advisor\').reset_index()\n        dataframe=dataframe.rename(columns={\'index\':\'Keyword\'})\n\n        dataframe = dataframe[["Advisor",\'Keyword\']]\n    except:\n            pass\n    numero+=1\n    \nprint(dataframe)\n'

# %% [markdown]
# # Script para recuperar los keywords y advisors del repositorio

# %%
#23 de Abril de 2021
import requests
import pandas as pd
from bs4 import BeautifulSoup

d = {} 
numero=5080
#dataframe=None
for count in range(0,10):
    programa=None
    advisor=None
    validador=None
    try:
        URL='https://repository.usc.edu.co/handle/20.500.12421/'+str(numero)+'?show=full'
        estructura = requests.get(URL,verify=False).text
        contenido = BeautifulSoup(estructura, "lxml")
        #Lista para capturar los tr del documento html
        dastosr=[]

        for datos in contenido.find_all('tr'):
            validador=datos.text.replace('\n', '').strip()
            dastosr.append(datos.text.replace('\n', ' ').strip())
            if validador.startswith('dc.contributor.advisor'):
                advisor=validador[22:]
            if validador.startswith('dc.publisher.program'):
                programa=validador[20:]
        #advisor=dastosr[0].replace('dc.contributor.advisor', '').strip()
        #No es posible encontrar el programa según un orden establecido
        #programa=dastosr[-2]
            if programa=='Ingeniería Industrial':
                
                datostextoesp=[]
                for valoresp in dastosr:
                        if valoresp.startswith('dc.subject'):
                            datostextoesp.append(valoresp[10:])

                datostextoesp_=[]
                for valoresp_ in datostextoesp:
                        if not valoresp_.startswith('.keyword'):
                            datostextoesp_.append(valoresp_.replace('es_ES', '').strip())

                #construcción de un diccionario
                resultados = datostextoesp_
                count = advisor

                for i in resultados:
                    d[i] = advisor



                dataframe=pd.Series(d).to_frame('Advisor').reset_index()
                dataframe=dataframe.rename(columns={'index':'Keyword'})

                dataframe = dataframe[["Advisor",'Keyword']]
                dataframe['Programa']=programa
    except:
        pass
    numero+=1
    
print(dataframe)
# Out:
# C:\Users\HP\anaconda3\lib\site-packages\urllib3\connectionpool.py:979: InsecureRequestWarning: Unverified HTTPS request is being made to host 'repository.usc.edu.co'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# C:\Users\HP\anaconda3\lib\site-packages\urllib3\connectionpool.py:979: InsecureRequestWarning: Unverified HTTPS request is being made to host 'repository.usc.edu.co'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# C:\Users\HP\anaconda3\lib\site-packages\urllib3\connectionpool.py:979: InsecureRequestWarning: Unverified HTTPS request is being made to host 'repository.usc.edu.co'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# C:\Users\HP\anaconda3\lib\site-packages\urllib3\connectionpool.py:979: InsecureRequestWarning: Unverified HTTPS request is being made to host 'repository.usc.edu.co'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# C:\Users\HP\anaconda3\lib\site-packages\urllib3\connectionpool.py:979: InsecureRequestWarning: Unverified HTTPS request is being made to host 'repository.usc.edu.co'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# C:\Users\HP\anaconda3\lib\site-packages\urllib3\connectionpool.py:979: InsecureRequestWarning: Unverified HTTPS request is being made to host 'repository.usc.edu.co'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# C:\Users\HP\anaconda3\lib\site-packages\urllib3\connectionpool.py:979: InsecureRequestWarning: Unverified HTTPS request is being made to host 'repository.usc.edu.co'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# C:\Users\HP\anaconda3\lib\site-packages\urllib3\connectionpool.py:979: InsecureRequestWarning: Unverified HTTPS request is being made to host 'repository.usc.edu.co'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# C:\Users\HP\anaconda3\lib\site-packages\urllib3\connectionpool.py:979: InsecureRequestWarning: Unverified HTTPS request is being made to host 'repository.usc.edu.co'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# C:\Users\HP\anaconda3\lib\site-packages\urllib3\connectionpool.py:979: InsecureRequestWarning: Unverified HTTPS request is being made to host 'repository.usc.edu.co'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
#                            Advisor                             Keyword  \
# 0     Salazar Ramos, Andrés Felipe  Simulación Y Estimación Del Tiempo
# 1     Salazar Ramos, Andrés Felipe     Lanzamiento De Nuevos Productos
# 2     Salazar Ramos, Andrés Felipe                       Incertidumbre
# 3     Salazar Ramos, Andrés Felipe               Gerencia De Proyectos
# 4      Garcia Jiménez, Juan Camilo                               Pymes
# 5      Garcia Jiménez, Juan Camilo                                 SST
# 6      Garcia Jiménez, Juan Camilo                         OHSAS 18001
# 7      Garcia Jiménez, Juan Camilo                           ISO 45001
# 8   Ramírez Guespud, Julián Andrés                 Energías Renovables
# 9   Ramírez Guespud, Julián Andrés                Sectores Productivos
# 10  Ramírez Guespud, Julián Andrés                Impactos Ambientales
# 11  Ramírez Guespud, Julián Andrés        Sistema De Gestión Ambiental
# 12      Bernal Suárez, Diana Paola         Gestión De Residuos Sólidos
# 13      Bernal Suárez, Diana Paola                   Logística Inversa
# 14      Bernal Suárez, Diana Paola                   Economía Circular
# 15    Parra Valdés, Daniel Alberto                      Automatización
# 16    Parra Valdés, Daniel Alberto                            Procesos
# 17    Parra Valdés, Daniel Alberto                      Implementación
# 18    Parra Valdés, Daniel Alberto                     Mejora Continua
#
#                  Programa
# 0   Ingeniería Industrial
# 1   Ingeniería Industrial
# 2   Ingeniería Industrial
# 3   Ingeniería Industrial
# 4   Ingeniería Industrial
# 5   Ingeniería Industrial
# 6   Ingeniería Industrial
# 7   Ingeniería Industrial
# 8   Ingeniería Industrial
# 9   Ingeniería Industrial
# 10  Ingeniería Industrial
# 11  Ingeniería Industrial
# 12  Ingeniería Industrial
# 13  Ingeniería Industrial
# 14  Ingeniería Industrial
# 15  Ingeniería Industrial
# 16  Ingeniería Industrial
# 17  Ingeniería Industrial
# 18  Ingeniería Industrial

# %%
dataframe
# Out:
#                            Advisor                             Keyword  \
# 0     Salazar Ramos, Andrés Felipe  Simulación Y Estimación Del Tiempo
# 1     Salazar Ramos, Andrés Felipe     Lanzamiento De Nuevos Productos
# 2     Salazar Ramos, Andrés Felipe                       Incertidumbre
# 3     Salazar Ramos, Andrés Felipe               Gerencia De Proyectos
# 4      Garcia Jiménez, Juan Camilo                               Pymes
# 5      Garcia Jiménez, Juan Camilo                                 SST
# 6      Garcia Jiménez, Juan Camilo                         OHSAS 18001
# 7      Garcia Jiménez, Juan Camilo                           ISO 45001
# 8   Ramírez Guespud, Julián Andrés                 Energías Renovables
# 9   Ramírez Guespud, Julián Andrés                Sectores Productivos
# 10  Ramírez Guespud, Julián Andrés                Impactos Ambientales
# 11  Ramírez Guespud, Julián Andrés        Sistema De Gestión Ambiental
# 12      Bernal Suárez, Diana Paola         Gestión De Residuos Sólidos
# 13      Bernal Suárez, Diana Paola                   Logística Inversa
# 14      Bernal Suárez, Diana Paola                   Economía Circular
# 15    Parra Valdés, Daniel Alberto                      Automatización
# 16    Parra Valdés, Daniel Alberto                            Procesos
# 17    Parra Valdés, Daniel Alberto                      Implementación
# 18    Parra Valdés, Daniel Alberto                     Mejora Continua
#
#                  Programa
# 0   Ingeniería Industrial
# 1   Ingeniería Industrial
# 2   Ingeniería Industrial
# 3   Ingeniería Industrial
# 4   Ingeniería Industrial
# 5   Ingeniería Industrial
# 6   Ingeniería Industrial
# 7   Ingeniería Industrial
# 8   Ingeniería Industrial
# 9   Ingeniería Industrial
# 10  Ingeniería Industrial
# 11  Ingeniería Industrial
# 12  Ingeniería Industrial
# 13  Ingeniería Industrial
# 14  Ingeniería Industrial
# 15  Ingeniería Industrial
# 16  Ingeniería Industrial
# 17  Ingeniería Industrial
# 18  Ingeniería Industrial

# %%
programa
# Out:
# 'dc.subject.keywordUncertainty'

# %%
dataframe
# Out:
#                               Advisor                      Keyword
# 0     Rivera Sánchez, Sandra Patricia                    Filtroses
# 1     Rivera Sánchez, Sandra Patricia  Número Más Probable (NMP)es
# 2         Mantilla Redondo, José Luis                    Calidades
# 3     Rivera Sánchez, Sandra Patricia                       Aguaes
# 4     Rivera Sánchez, Sandra Patricia                 Salmonellaes
# ...                               ...                          ...
# 3714         Beltrán García, Leonardo             Comercialización
# 3715         Beltrán García, Leonardo                  Exportación
# 3716        Robayo Avendaño, Angélica     Investigación De Mercado
# 3717        Robayo Avendaño, Angélica   Recolección De Información
# 3718        Robayo Avendaño, Angélica                  Encuestador
#
# [3719 rows x 2 columns]

# %%
dataframe

# %%
programa
# Out:
# 'dc.publisher.programMaestría en Derecho Médico'

# %% [markdown]
# # Notebook para revisar los modelos de la aplicación

# %%
import requests
URL = 'https://repository.usc.edu.co/handle/20.500.12421/5080?show=full'
page = requests.get(URL,verify=False)
# Out:
# C:\Users\HP\anaconda3\lib\site-packages\urllib3\connectionpool.py:979: InsecureRequestWarning: Unverified HTTPS request is being made to host 'repository.usc.edu.co'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(

# %%
page.content
# Out:
# b'<!DOCTYPE html>\n            <!--[if lt IE 7]> <html class="no-js lt-ie9 lt-ie8 lt-ie7" lang="en"> <![endif]-->\n            <!--[if IE 7]>    <html class="no-js lt-ie9 lt-ie8" lang="en"> <![endif]-->\n            <!--[if IE 8]>    <html class="no-js lt-ie9" lang="en"> <![endif]-->\n            <!--[if gt IE 8]><!--> <html class="no-js" lang="en"> <!--<![endif]-->\n            <head><META http-equiv="Content-Type" content="text/html; charset=UTF-8">\n<meta content="text/html; charset=UTF-8" http-equiv="Content-Type">\n<meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible">\n<meta content="width=device-width,initial-scale=1" name="viewport">\n<link rel="shortcut icon" href="/themes/Mirage2/images/favicon.ico">\n<link rel="apple-touch-icon" href="/themes/Mirage2/images/apple-touch-icon.png">\n<meta name="Generator" content="DSpace 6.3">\n<link href="/themes/Mirage2/styles/main.css" rel="stylesheet">\n<link type="application/opensearchdescription+xml" rel="search" href="https://repository.usc.edu.co:443/open-search/description.xml" title="DSpace">\n<script>\n                //Clear default text of empty text areas on focus\n                function tFocus(element)\n                {\n                if (element.value == \' \'){element.value=\'\';}\n                }\n                //Clear default text of empty text areas on submit\n                function tSubmit(form)\n                {\n                var defaultedElements = document.getElementsByTagName("textarea");\n                for (var i=0; i != defaultedElements.length; i++){\n                if (defaultedElements[i].value == \' \'){\n                defaultedElements[i].value=\'\';}}\n                }\n                //Disable pressing \'enter\' key to submit a form (otherwise pressing \'enter\' causes a submission to start over)\n                function disableEnterKey(e)\n                {\n                var key;\n\n                if(window.event)\n                key = window.event.keyCode;     //Internet Explorer\n                else\n                key = e.which;     //Firefox and Netscape\n\n                if(key == 13)  //if "Enter" pressed, then disable!\n                return false;\n                else\n                return true;\n                }\n            </script><!--[if lt IE 9]>\n                <script src="/themes/Mirage2/vendor/html5shiv/dist/html5shiv.js">\xc2\xa0</script>\n                <script src="/themes/Mirage2/vendor/respond/dest/respond.min.js">\xc2\xa0</script>\n                <![endif]--><script src="/themes/Mirage2/vendor/modernizr/modernizr.js">\xc2\xa0</script>\n<title>Simulaci&oacute;n y estimaci&oacute;n del tiempo esperado en la gesti&oacute;n de un proyecto en una empresa de alimentos.</title>\r\n<link rel="schema.DCTERMS" href="http://purl.org/dc/terms/" />\r\n<link rel="schema.DC" href="http://purl.org/dc/elements/1.1/" />\r\n<meta name="DC.contributor" content="Salazar Ramos, Andr\xc3\xa9s Felipe" />\r\n<meta name="DC.creator" content="Mena Ibarg\xc3\xbcen, Gina Alexandra" />\r\n<meta name="DCTERMS.dateAccepted" content="2020-11-27T14:18:17Z" scheme="DCTERMS.W3CDTF" />\r\n<meta name="DCTERMS.available" content="2020-11-27T14:18:17Z" scheme="DCTERMS.W3CDTF" />\r\n<meta name="DCTERMS.issued" content="2020" scheme="DCTERMS.W3CDTF" />\r\n<meta name="DCTERMS.bibliographicCitation" content="Mena Ibarg\xc3\xbcen, G. A. (2020). Simulaci\xc3\xb3n y estimaci\xc3\xb3n del tiempo esperado en la gesti\xc3\xb3n de un proyecto en una empresa de alimentos. Universidad Santiago de Cali." xml:lang="es_ES" />\r\n<meta name="DC.identifier" content="https://repository.usc.edu.co/handle/20.500.12421/5080" scheme="DCTERMS.URI" />\r\n<meta name="DC.description" content="En este art\xc3\xadculo se presenta la propuesta de simulaci\xc3\xb3n y estimaci\xc3\xb3n del tiempo esperado en la gesti\xc3\xb3n de un proyecto para el&#xD;&#xA;lanzamiento de nuevos productos, en una empresa de alimentos fabricante y comerciante de chips ...

# %%
from bs4 import BeautifulSoup

# %%
html_content = requests.get(URL,verify=False).text
# Out:
# C:\Users\HP\anaconda3\lib\site-packages\urllib3\connectionpool.py:979: InsecureRequestWarning: Unverified HTTPS request is being made to host 'repository.usc.edu.co'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(

# %%
soup = BeautifulSoup(html_content, "lxml")

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <!--[if lt IE 7]> <html class="no-js lt-ie9 lt-ie8 lt-ie7" lang="en"> <![endif]-->
# <!--[if IE 7]>    <html class="no-js lt-ie9 lt-ie8" lang="en"> <![endif]-->
# <!--[if IE 8]>    <html class="no-js lt-ie9" lang="en"> <![endif]-->
# <!--[if gt IE 8]><!-->
# <html class="no-js" lang="en">
#  <!--<![endif]-->
#  <head>
#   <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
#   <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
#   <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/>
#   <meta content="width=device-width,initial-scale=1" name="viewport"/>
#   <link href="/themes/Mirage2/images/favicon.ico" rel="shortcut icon"/>
#   <link href="/themes/Mirage2/images/apple-touch-icon.png" rel="apple-touch-icon"/>
#   <meta content="DSpace 6.3" name="Generator"/>
#   <link href="/themes/Mirage2/styles/main.css" rel="stylesheet"/>
#   <link href="https://repository.usc.edu.co:443/open-search/description.xml" rel="search" title="DSpace" type="application/opensearchdescription+xml"/>
#   <script>
#    //Clear default text of empty text areas on focus
#                 function tFocus(element)
#                 {
#                 if (element.value == ' '){element.value='';}
#                 }
#                 //Clear default text of empty text areas on submit
#                 function tSubmit(form)
#                 {
#                 var defaultedElements = document.getElementsByTagName("textarea");
#                 for (var i=0; i != defaultedElements.length; i++){
#                 if (defaultedElements[i].value == ' '){
#                 defaultedElements[i].value='';}}
#                 }
#                 //Disable pressing 'enter' key to submit a form (otherwise pressing 'enter' causes a submission to start over)
#                 function disableEnterKey(e)
#                 {
#                 var key;
#
#                 if(window.event)
#                 key = window.event.keyCode;     //Internet Explorer
#                 else
#                 key = e.which;     //Firefox and Netscape
#
#                 if(key == 13)  //if "Enter" pressed, then disable!
#                 return false;
#                 else
#                 return true;
#                 }
#   </script>
#   <!--[if lt IE 9]>
#                 <script src="/themes/Mirage2/vendor/html5shiv/dist/html5shiv.js"> </script>
#                 <script src="/themes/Mirage2/vendor/respond/dest/respond.min.js"> </script>
#                 <![endif]-->
#   <script src="/themes/Mirage2/vendor/modernizr/modernizr.js">
#   </script>
#   <title>
#    Simulación y estimación del tiempo esperado en la gestión de un proyecto en una empresa de alimentos.
#   </title>
#   <link href="http://purl.org/dc/terms/" rel="schema.DCTERMS"/>
#   <link href="http://purl.org/dc/elements/1.1/" rel="schema.DC"/>
#   <meta content="Salazar Ramos, Andrés Felipe" name="DC.contributor"/>
#   <meta content="Mena Ibargüen, Gina Alexandra" name="DC.creator"/>
#   <meta content="2020-11-27T14:18:17Z" name="DCTERMS.dateAccepted" scheme="DCTERMS.W3CDTF"/>
#   <meta content="2020-11-27T14:18:17Z" name="DCTERMS.available" scheme="DCTERMS.W3CDTF"/>
#   <meta content="2020" name="DCTERMS.issued" scheme="DCTERMS.W3CDTF"/>
#   <meta content="Mena Ibargüen, G. A. (2020). Simulación y estimación del tiempo esperado en la gestión de un proyecto en una empresa de alimentos. Universidad Santiago de Cali." name="DCTERMS.bibliographicCitation" xml:lang="es_ES"/>
#   <meta content="https://repository.usc.edu.co/handle/20.500.12421/5080" name="DC.identifier" scheme="DCTERMS.URI"/>
#   <meta content="En este artículo se presenta la propuesta de simulación y estimación del tiempo esperado en la gestión de un proyecto para el
# lanzamiento de nuevos productos, en una empresa de alimentos fabricante y comerciante de chips de maíz, papitas fritas y otros
# aperitivos, realizando la identificación, atención de los posibles riesgos dentro de la gestión del proyecto con el fin de
# implementar un plan de mejoramiento que permita mitigar, controlar y dar tratamiento a aquellos riesgos que generen un
# impacto negativo y puedan impedir el cumplimiento de los tiempos establecidos para cada actividad del proyecto. Para dar
# cumplimiento con los objetivos propuestos se utilizó la metodología de Simulación Montecarlo, buscando calcular probabilidades
# con secuencias de números aleatorios." name="DC.description" xml:lang="es_ES"/>
#   <meta content="The article presents the proposed simulation and modification of the expected time in the management of a project for the launch of
# new products, in a food company that manufactures and markets corn chips, French fries and other snacks, identify, the possible
# risks within the project management in order to implement an improvement plan that allows mitigating, controlling and treating those
# risks that generate a negative impact and can avoid meeting the times established for each project activity. To meet the proposed
# objectives, the Monte Carlo simulation methodology was used, seeking to calculate the challenges with sequences of random
# numbers." name="DCTERMS.abstract" xml:lang="es_ES"/>
#   <meta content="application/pdf" name="DC.format"/>
#   <meta content="18 páginas" name="DCTERMS.extent"/>
#   <meta content="es" name="DC.language" scheme="DCTERMS.RFC1766" xml:lang="es_ES"/>
#   <meta content="Universidad Santiago de Cali" name="DC.publisher" xml:lang="es_ES"/>
#   <meta content="https://creativecommons.org/licenses/by/4.0/" name="DC.rights" scheme="DCTERMS.URI"/>
#   <meta content="Simulación Y Estimación Del Tiempo" name="DC.subject" xml:lang="es_ES"/>
#   <meta content="Lanzamiento De Nuevos Productos" name="DC.subject" xml:lang="es_ES"/>
#   <meta content="Incertidumbre" name="DC.subject" xml:lang="es_ES"/>
#   <meta content="Gerencia De Proyectos" name="DC.subject" xml:lang="es_ES"/>
#   <meta content="Simulación y estimación del tiempo esperado en la gestión de un proyecto en una empresa de alimentos." name="DC.title" xml:lang="es_ES"/>
#   <meta content="Thesis" name="DC.type" xml:lang="es_ES"/>
#   <meta content="Facultad de Ingeniería" name="DC.publisher"/>
#   <meta content="Acceso Abierto" name="DC.rights"/>
#   <meta content="Reconocimiento 4.0 Internacional (CC BY 4.0)" name="DC.rights"/>
#   <meta content="Repositorio Institucional USC" name="DC.source"/>
#   <meta content="Universidad Santiago de Cali" name="DC.source"/>
#   <meta content="Articulo" name="DC.type"/>
#   <meta content="Trabajo de grado para optar al título de Ingeniero Industrial" name="DC.creator"/>
#   <meta content="Ingeniería Industrial" name="DC.publisher"/>
#   <meta content="Simulation And Time Modification" name="DC.subject"/>
#   <meta content="Launch Of New Products" name="DC.subject"/>
#   <meta content="Uncertainty" name="DC.subject"/>
#   <meta content="Project Management" name="DC.subject"/>
#   <meta content="Simulación Y Estimación Del Tiempo; Lanzamiento De Nuevos Productos; Incertidumbre; Gerencia De Proyectos; Thesis" name="citation_keywords"/>
#   <meta content="Universidad Santiago de Cali" name="citation_dissertation_institution"/>
#   <meta content="Simulación y estimación del tiempo esperado en la gestión de un proyecto en una empresa de alimentos." name="citation_title"/>
#   <meta content="Simulación y estimación del tiempo esperado en la gestión de un proyecto en una empresa de alimentos." name="citation_dissertation_name"/>
#   <meta content="es" name="citation_language"/>
#   <meta content="Mena Ibargüen, Gina Alexandra" name="citation_author"/>
#   <meta content="https://repository.usc.edu.co/bitstream/20.500.12421/5080/3/SIMULACI%c3%93N%20Y%20ESTIMACI%c3%93N.pdf" name="citation_pdf_url"/>
#   <meta content="2020" name="citation_date"/>
#   <meta content="https://repository.usc.edu.co/handle/20.500.12421/5080" name="citation_abstract_html_url"/>
#  </head>
#  <body>
#   <header>
#    <div class="navbar navbar-default navbar-static-top" role="navigation">
#     <div class="container">
#      <div class="navbar-header">
#       <button class="navbar-toggle" data-toggle="offcanvas" type="button">
#        <span class="sr-only">
#         Cambiar navegación
#        </span>
#        <span class="icon-bar">
#        </span>
#        <span class="icon-bar">
#        </span>
#        <span class="icon-bar">
#        </span>
#       </button>
#       <a class="navbar-brand" href="/">
#        <img src="/themes/Mirage2/images/DSpace-logo-line.svg"/>
#       </a>
#       <div class="navbar-header pull-right visible-xs hidden-sm hidden-md hidden-lg">
#        <ul class="nav nav-pills pull-left">
#         <li class="dropdown" id="ds-language-selection-xs">
#          <button class="dropdown-toggle navbar-toggle navbar-link" data-toggle="dropdown" href="#" id="language-dropdown-toggle-xs" role="button">
#           <b aria-hidden="true" class="visible-xs glyphicon glyphicon-globe">
#           </b>
#          </button>
#          <ul aria-labelledby="language-dropdown-toggle-xs" class="dropdown-menu pull-right" data-no-collapse="true" role="menu">
#           <li class="disabled" role="presentation">
#            <a href="https://repository.usc.edu.co:443/handle/20.500.12421/5080?locale-attribute=es">
#             español
#            </a>
#           </li>
#           <li role="presentation">
#            <a href="https://repository.usc.edu.co:443/handle/20.500.12421/5080?locale-attribute=en">
#             English
#            </a>
#           </li>
#          </ul>
#         </li>
#         <li>
#          <form action="/login" method="get" style="display: inline">
#           <button class="navbar-toggle navbar-link">
#            <b aria-hidden="true" class="visible-xs glyphicon glyphicon-user">
#            </b>
#           </button>
#          </form>
#         </li>
#        </ul>
#       </div>
#      </div>
#      <div class="navbar-header pull-right hidden-xs">
#       <ul class="nav navbar-nav pull-left">
#        <li class="dropdown" id="ds-language-selection">
#         <a class="dropdown-toggle" data-toggle="dropdown" href="#" id="language-dropdown-toggle" role="button">
#          <span class="hidden-xs">
#           español
#           <b class="caret">
#           </b>
#          </span>
#         </a>
#         <ul aria-labelledby="language-dropdown-toggle" class="dropdown-menu pull-right" data-no-collapse="true" role="menu">
#          <li class="disabled" role="presentation">
#           <a href="?show=full&amp;locale-attribute=es">
#            español
#           </a>
#          </li>
#          <li role="presentation">
#           <a href="?show=full&amp;locale-attribute=en">
#            English
#           </a>
#          </li>
#         </ul>
#        </li>
#       </ul>
#       <ul class="nav navbar-nav pull-left">
#        <li>
#         <a href="/login">
#          <span class="hidden-xs">
#           Login
#          </span>
#         </a>
#        </li>
#       </ul>
#       <button class="navbar-toggle visible-sm" data-toggle="offcanvas" type="button">
#        <span class="sr-only">
#         Cambiar navegación
#        </span>
#        <span class="icon-bar">
#        </span>
#        <span class="icon-bar">
#        </span>
#        <span class="icon-bar">
#        </span>
#       </button>
#      </div>
#     </div>
#    </div>
#   </header>
#   <div class="trail-wrapper hidden-print">
#    <div class="container">
#     <div class="row">
#      <div class="col-xs-12">
#       <div class="breadcrumb dropdown visible-xs">
#        <a class="dropdown-toggle" data-toggle="dropdown" href="#" id="trail-dropdown-toggle" role="button">
#         Ver ítem
#         <b class="caret">
#         </b>
#        </a>
#        <ul aria-labelledby="trail-dropdown-toggle" class="dropdown-menu" role="menu">
#         <li role="presentation">
#          <a href="/" role="menuitem">
#           <i aria-hidden="true" class="glyphicon glyphicon-home">
#           </i>
#           DSpace Principal
#          </a>
#         </li>
#         <li role="presentation">
#          <a href="/handle/20.500.12421/5" role="menuitem">
#           A. Trabajos de Grado
#          </a>
#         </li>
#         <li role="presentation">
#          <a href="/handle/20.500.12421/13" role="menuitem">
#           Pregrado
#          </a>
#         </li>
#         <li role="presentation">
#          <a href="/handle/20.500.12421/43" role="menuitem">
#           Facultad de Ingeniería
#          </a>
#         </li>
#         <li role="presentation">
#          <a href="/handle/20.500.12421/49" role="menuitem">
#           Ingeniería Industrial
#          </a>
#         </li>
#         <li class="disabled" role="presentation">
#          <a href="#" role="menuitem">
#           Ver ítem
#          </a>
#         </li>
#        </ul>
#       </div>
#       <ul class="breadcrumb hidden-xs">
#        <li>
#         <i aria-hidden="true" class="glyphicon glyphicon-home">
#         </i>
#         <a href="/">
#          DSpace Principal
#         </a>
#        </li>
#        <li>
#         <a href="/handle/20.500.12421/5">
#          A. Trabajos de Grado
#         </a>
#        </li>
#        <li>
#         <a href="/handle/20.500.12421/13">
#          Pregrado
#         </a>
#        </li>
#        <li>
#         <a href="/handle/20.500.12421/43">
#          Facultad de Ingeniería
#         </a>
#        </li>
#        <li>
#         <a href="/handle/20.500.12421/49">
#          Ingeniería Industrial
#         </a>
#        </li>
#        <li class="active">
#         Ver ítem
#        </li>
#       </ul>
#      </div>
#     </div>
#    </div>
#   </div>
#   <div class="hidden" id="no-js-warning-wrapper">
#    <div id="no-js-warning">
#     <div class="notice failure">
#      JavaScript is disabled for your browser. Some features of this site may not work without it.
#     </div>
#    </div>
#   </div>
#   <div class="container" id="main-container">
#    <div class="row row-offcanvas row-offcanvas-right">
#     <div class="horizontal-slider clearfix">
#      <div class="col-xs-12 col-sm-12 col-md-9 main-content">
#       <div>
#        <div class="ds-static-div primary" id="aspect_artifactbrowser_ItemViewer_div_item-view">
#         <p class="ds-paragraph item-view-toggle item-view-toggle-top">
#          <a href="/handle/20.500.12421/5080">
#           Mostrar el registro sencillo del ítem
#          </a>
#         </p>
#         <!-- External Metadata URL: cocoon://metadata/handle/20.500.12421/5080/mets.xml-->
#         <h2 class="page-header first-page-header">
#          Simulación y estimación del tiempo esperado en la gestión de un proyecto en una empresa de alimentos.
#         </h2>
#         <div class="ds-table-responsive">
#          <table class="ds-includeSet-table detailtable table table-striped table-hover">
#           <tr class="ds-table-row odd">
#            <td class="label-cell">
#             dc.contributor.advisor
#            </td>
#            <td class="word-break">
#             Salazar Ramos, Andrés Felipe
#            </td>
#            <td>
#            </td>
#           </tr>
#           <tr class="ds-table-row even">
#            <td class="label-cell">
#             dc.contributor.author
#            </td>
#            <td class="word-break">
#             Mena Ibargüen, Gina Alexandra
#            </td>
#            <td>
#            </td>
#           </tr>
#           <tr class="ds-table-row odd">
#            <td class="label-cell">
#             dc.date.accessioned
#            </td>
#            <td class="word-break">
#             2020-11-27T14:18:17Z
#            </td>
#            <td>
#            </td>
#           </tr>
#           <tr class="ds-table-row even">
#            <td class="label-cell">
#             dc.date.available
#            </td>
#            <td class="word-break">
#             2020-11-27T14:18:17Z
#            </td>
#            <td>
#            </td>
#           </tr>
#           <tr class="ds-table-row odd">
#            <td class="label-cell">
#             dc.date.issued
#            </td>
#            <td class="word-break">
#             2020
#            </td>
#            <td>
#            </td>
#           </tr>
#           <tr class="ds-table-row even">
#            <td class="label-cell">
#             dc.identifier.citation
#            </td>
#            <td class="word-break">
#             Mena Ibargüen, G. A. (2020). Simulación y estimación del tiempo esperado en la gestión de un proyecto en una empresa de alimentos. Universidad Santiago de Cali.
#            </td>
#            <td>
#             es_ES
#            </td>
#           </tr>
#           <tr class="ds-table-row odd">
#            <td class="label-cell">
#             dc.identifier.uri
#            </td>
#            <td class="word-break">
#             https://repository.usc.edu.co/handle/20.500.12421/5080
#            </td>
#            <td>
#            </td>
#           </tr>
#           <tr class="ds-table-row even">
#            <td class="label-cell">
#             dc.description
#            </td>
#            <td class="word-break">
#             En este artículo se presenta la propuesta de simulación y estimación del tiempo esperado en la gestión de un proyecto para el
# lanzamiento de nuevos productos, en una empresa de alimentos fabricante y comerciante de chips de maíz, papitas fritas y otros
# aperitivos, realizando la identificación, atención de los posibles riesgos dentro de la gestión del proyecto con el fin de
# implementar un plan de mejoramiento que permita mitigar, controlar y dar tratamiento a aquellos riesgos que generen un
# impacto negativo y puedan impedir el cumplimiento de los tiempos establecidos para cada actividad del proyecto. Para dar
# cumplimiento con los objetivos propuestos se utilizó la metodología de Simulación Montecarlo, buscando calcular probabilidades
# con secuencias de números aleatorios.
#            </td>
#            <td>
#             es_ES
#            </td>
#           </tr>
#           <tr class="ds-table-row odd">
#            <td class="label-cell">
#             dc.description.abstract
#            </td>
#            <td class="word-break">
#             The article presents the proposed simulation and modification of the expected time in the management of a project for the launch of
# new products, in a food company that manufactures and markets corn chips, French fries and other snacks, identify, the possible
# risks within the project management in order to implement an improvement plan that allows mitigating, controlling and treating those
# risks that generate a negative impact and can avoid meeting the times established for each project activity. To meet the proposed
# objectives, the Monte Carlo simulation methodology was used, seeking to calculate the challenges with sequences of random
# numbers.
#            </td>
#            <td>
#             es_ES
#            </td>
#           </tr>
#           <tr class="ds-table-row even">
#            <td class="label-cell">
#             dc.format
#            </td>
#            <td class="word-break">
#             application/pdf
#            </td>
#            <td>
#            </td>
#           </tr>
#           <tr class="ds-table-row odd">
#            <td class="label-cell">
#             dc.format.extent
#            </td>
#            <td class="word-break">
#             18 páginas
#            </td>
#            <td>
#            </td>
#           </tr>
#           <tr class="ds-table-row even">
#            <td class="label-cell">
#             dc.language.iso
#            </td>
#            <td class="word-break">
#             es
#            </td>
#            <td>
#             es_ES
#            </td>
#           </tr>
#           <tr class="ds-table-row odd">
#            <td class="label-cell">
#             dc.publisher
#            </td>
#            <td class="word-break">
#             Universidad Santiago de Cali
#            </td>
#            <td>
#             es_ES
#            </td>
#           </tr>
#           <tr class="ds-table-row even">
#            <td class="label-cell">
#             dc.rights.uri
#            </td>
#            <td class="word-break">
#             https://creativecommons.org/licenses/by/4.0/
#            </td>
#            <td>
#            </td>
#           </tr>
#           <tr class="ds-table-row odd">
#            <td class="label-cell">
#             dc.subject
#            </td>
#            <td class="word-break">
#             Simulación Y Estimación Del Tiempo
#            </td>
#            <td>
#             es_ES
#            </td>
#           </tr>
#           <tr class="ds-table-row even">
#            <td class="label-cell">
#             dc.subject
#            </td>
#            <td class="word-break">
#             Lanzamiento De Nuevos Productos
#            </td>
#            <td>
#             es_ES
#            </td>
#           </tr>
#           <tr class="ds-table-row odd">
#            <td class="label-cell">
#             dc.subject
#            </td>
#            <td class="word-break">
#             Incertidumbre
#            </td>
#            <td>
#             es_ES
#            </td>
#           </tr>
#           <tr class="ds-table-row even">
#            <td class="label-cell">
#             dc.subject
#            </td>
#            <td class="word-break">
#             Gerencia De Proyectos
#            </td>
#            <td>
#             es_ES
#            </td>
#           </tr>
#           <tr class="ds-table-row odd">
#            <td class="label-cell">
#             dc.title
#            </td>
#            <td class="word-break">
#             Simulación y estimación del tiempo esperado en la gestión de un proyecto en una empresa de alimentos.
#            </td>
#            <td>
#             es_ES
#            </td>
#           </tr>
#           <tr class="ds-table-row even">
#            <td class="label-cell">
#             dc.type
#            </td>
#            <td class="word-break">
#             Thesis
#            </td>
#            <td>
#             es_ES
#            </td>
#           </tr>
#           <tr class="ds-table-row odd">
#            <td class="label-cell">
#             dc.publisher.faculty
#            </td>
#            <td class="word-break">
#             Facultad de Ingeniería
#            </td>
#            <td>
#            </td>
#           </tr>
#           <tr class="ds-table-row even">
#            <td class="label-cell">
#             dc.pubplace.city
#            </td>
#            <td class="word-break">
#             Cali
#            </td>
#            <td>
#            </td>
#           </tr>
#           <tr class="ds-table-row odd">
#            <td class="label-cell">
#             dc.rights.acceso
#            </td>
#            <td class="word-break">
#             Acceso Abierto
#            </td>
#            <td>
#            </td>
#           </tr>
#           <tr class="ds-table-row even">
#            <td class="label-cell">
#             dc.rights.cc
#            </td>
#            <td class="word-break">
#             Reconocimiento 4.0 Internacional (CC BY 4.0)
#            </td>
#            <td>
#            </td>
#           </tr>
#           <tr class="ds-table-row odd">
#            <td class="label-cell">
#             dc.source.repository
#            </td>
#            <td class="word-break">
#             Repositorio Institucional USC
#            </td>
#            <td>
#            </td>
#           </tr>
#           <tr class="ds-table-row even">
#            <td class="label-cell">
#             dc.source.institution
#            </td>
#            <td class="word-break">
#             Universidad Santiago de Cali
#            </td>
#            <td>
#            </td>
#           </tr>
#           <tr class="ds-table-row odd">
#            <td class="label-cell">
#             dc.type.spa
#            </td>
#            <td class="word-break">
#             Articulo
#            </td>
#            <td>
#            </td>
#           </tr>
#           <tr class="ds-table-row even">
#            <td class="label-cell">
#             dc.creator.degree
#            </td>
#            <td class="word-break">
#             Trabajo de grado para optar al título de Ingeniero Industrial
#            </td>
#            <td>
#            </td>
#           </tr>
#           <tr class="ds-table-row odd">
#            <td class="label-cell">
#             dc.publisher.program
#            </td>
#            <td class="word-break">
#             Ingeniería Industrial
#            </td>
#            <td>
#            </td>
#           </tr>
#           <tr class="ds-table-row even">
#            <td class="label-cell">
#             dc.pubplace.state
#            </td>
#            <td class="word-break">
#             Valle del Cauca
#            </td>
#            <td>
#            </td>
#           </tr>
#           <tr class="ds-table-row odd">
#            <td class="label-cell">
#             dc.subject.keyword
#            </td>
#            <td class="word-break">
#             Simulation And Time Modification
#            </td>
#            <td>
#            </td>
#           </tr>
#           <tr class="ds-table-row even">
#            <td class="label-cell">
#             dc.subject.keyword
#            </td>
#            <td class="word-break">
#             Launch Of New Products
#            </td>
#            <td>
#            </td>
#           </tr>
#           <tr class="ds-table-row odd">
#            <td class="label-cell">
#             dc.subject.keyword
#            </td>
#            <td class="word-break">
#             Uncertainty
#            </td>
#            <td>
#            </td>
#           </tr>
#           <tr class="ds-table-row even">
#            <td class="label-cell">
#             dc.subject.keyword
#            </td>
#            <td class="word-break">
#             Project Management
#            </td>
#            <td>
#            </td>
#           </tr>
#          </table>
#         </div>
#         <span class="Z3988" title="ctx_ver=Z39.88-2004&amp;rft_val_fmt=info%3Aofi%2Ffmt%3Akev%3Amtx%3Adc&amp;rft_id=Mena+Ibarg%C3%BCen%2C+G.+A.+%282020%29.+Simulaci%C3%B3n+y+estimaci%C3%B3n+del+tiempo+esperado+en+la+gesti%C3%B3n+de+un+proyecto+en+una+empresa+de+alimentos.+Universidad+Santiago+de+Cali.&amp;rft_id=https%3A%2F%2Frepository.usc.edu.co%2Fhandle%2F20.500.12421%2F5080&amp;rfr_id=info%3Asid%2Fdspace.org%3Arepository&amp;">
#          ﻿
#         </span>
#         <h3>
#          Ficheros en el ítem
#         </h3>
#         <div class="file-list">
#          <div class="file-wrapper row">
#           <div class="col-xs-6 col-sm-3">
#            <div class="thumbnail">
#             <a class="image-link" href="/bitstream/handle/20.500.12421/5080/FORMATO%20AUTORIZACI%c3%93N.pdf?sequence=2&amp;isAllowed=y">
#              <img alt="Thumbnail" class="img-thumbnail" data-src="holder.js/100%x80/text:No Thumbnail"/>
#             </a>
#            </div>
#           </div>
#           <div class="col-xs-6 col-sm-7">
#            <dl class="file-metadata dl-horizontal">
#             <dt>
#              Nombre:
#             </dt>
#             <dd class="word-break" title="FORMATO AUTORIZACIÓN.pdf">
#              FORMATO AUTORIZACIÓN.pdf
#             </dd>
#             <dt>
#              Tamaño:
#             </dt>
#             <dd class="word-break">
#              393.0Kb
#             </dd>
#             <dt>
#              Formato:
#             </dt>
#             <dd class="word-break">
#              imagen JPEG
#             </dd>
#            </dl>
#           </div>
#           <div class="file-link col-xs-6 col-xs-offset-6 col-sm-2 col-sm-offset-0">
#            <a href="/bitstream/handle/20.500.12421/5080/FORMATO%20AUTORIZACI%c3%93N.pdf?sequence=2&amp;isAllowed=y">
#             Ver/
#            </a>
#           </div>
#          </div>
#          <div class="file-wrapper row">
#           <div class="col-xs-6 col-sm-3">
#            <div class="thumbnail">
#             <a class="image-link" href="/bitstream/handle/20.500.12421/5080/SIMULACI%c3%93N%20Y%20ESTIMACI%c3%93N.pdf?sequence=3&amp;isAllowed=y">
#              <img alt="Thumbnail" class="img-thumbnail" data-src="holder.js/100%x80/text:No Thumbnail"/>
#             </a>
#            </div>
#           </div>
#           <div class="col-xs-6 col-sm-7">
#            <dl class="file-metadata dl-horizontal">
#             <dt>
#              Nombre:
#             </dt>
#             <dd class="word-break" title="SIMULACIÓN Y ESTIMACIÓN.pdf">
#              SIMULACIÓN Y ESTIMACIÓN.pdf
#             </dd>
#             <dt>
#              Tamaño:
#             </dt>
#             <dd class="word-break">
#              823.9Kb
#             </dd>
#             <dt>
#              Formato:
#             </dt>
#             <dd class="word-break">
#              PDF
#             </dd>
#            </dl>
#           </div>
#           <div class="file-link col-xs-6 col-xs-offset-6 col-sm-2 col-sm-offset-0">
#            <a href="/bitstream/handle/20.500.12421/5080/SIMULACI%c3%93N%20Y%20ESTIMACI%c3%93N.pdf?sequence=3&amp;isAllowed=y">
#             Ver/
#            </a>
#           </div>
#          </div>
#         </div>
#         <h3 class="ds-list-head">
#          Este ítem aparece en la(s) siguiente(s) colección(ones)
#         </h3>
#         <ul class="ds-referenceSet-list">
#          <!-- External Metadata URL: cocoon://metadata/handle/20.500.12421/49/mets.xml-->
#          <li>
#           <a href="/handle/20.500.12421/49">
#            Ingeniería Industrial
#           </a>
#           <br/>
#          </li>
#         </ul>
#         <p class="ds-paragraph item-view-toggle item-view-toggle-bottom">
#          <a href="/handle/20.500.12421/5080">
#           Mostrar el registro sencillo del ítem
#          </a>
#         </p>
#        </div>
#        <div about="https://repository.usc.edu.co/handle/20.500.12421/5080" class="row">
#         <div class="col-sm-3 col-xs-12">
#          <a alt="https://creativecommons.org/licenses/by/4.0/" href="https://creativecommons.org/licenses/by/4.0/" rel="license" title="https://creativecommons.org/licenses/by/4.0/">
#           <img alt="https://creativecommons.org/licenses/by/4.0/" class="img-responsive" src="/themes/Mirage2//images/creativecommons/cc-generic.png"/>
#          </a>
#         </div>
#         <div class="col-sm-8">
#          <span>
#           Excepto si se señala otra cosa, la licencia del ítem se describe como https://creativecommons.org/licenses/by/4.0/
#          </span>
#         </div>
#        </div>
#       </div>
#       <div class="visible-xs visible-sm">
#        <footer>
#         <div class="row">
#          <hr/>
#          <div class="col-xs-7 col-sm-8">
#           <div>
#            <a href="http://www.dspace.org/" target="_blank">
#             DSpace software
#            </a>
#            copyright © 2002-2016
#            <a href="http://www.duraspace.org/" target="_blank">
#             DuraSpace
#            </a>
#           </div>
#           <div class="hidden-print">
#            <a href="/contact">
#             Contacto
#            </a>
#            |
#            <a href="/feedback">
#             Sugerencias
#            </a>
#           </div>
#          </div>
#          <div class="col-xs-5 col-sm-4 hidden-print">
#           <div class="pull-right">
#            <span class="theme-by">
#             Theme by
#            </span>
#            <br/>
#            <a href="http://atmire.com" target="_blank" title="Atmire NV">
#             <img alt="Atmire NV" src="/themes/Mirage2/images/atmire-logo-small.svg"/>
#            </a>
#           </div>
#          </div>
#         </div>
#         <a class="hidden" href="/htmlmap">
#         </a>
#         <p>
#         </p>
#        </footer>
#       </div>
#      </div>
#      <div class="col-xs-6 col-sm-3 sidebar-offcanvas" id="sidebar" role="navigation">
#       <div class="word-break hidden-print" id="ds-options">
#        <div class="ds-option-set" id="ds-search-option">
#         <form action="/discover" class="" id="ds-search-form" method="post">
#          <fieldset>
#           <div class="input-group">
#            <input class="ds-text-field form-control" name="query" placeholder="Búsquedas" type="text"/>
#            <span class="input-group-btn">
#             <button class="ds-button-field btn btn-primary" title="Ir">
#              <span aria-hidden="true" class="glyphicon glyphicon-search">
#              </span>
#             </button>
#            </span>
#           </div>
#           <div class="radio">
#            <label>
#             <input checked="" id="ds-search-form-scope-all" name="scope" type="radio" value=""/>
#             Buscar en DSpace
#            </label>
#           </div>
#           <div class="radio">
#            <label>
#             <input id="ds-search-form-scope-container" name="scope" type="radio" value="20.500.12421/49"/>
#             Esta colección
#            </label>
#           </div>
#          </fieldset>
#         </form>
#        </div>
#        <h2 class="ds-option-set-head h6">
#         Listar
#        </h2>
#        <div class="list-group" id="aspect_viewArtifacts_Navigation_list_browse">
#         <a class="list-group-item active">
#          <span class="h5 list-group-item-heading h5">
#           Todo DSpace
#          </span>
#         </a>
#         <a class="list-group-item ds-option" href="/community-list">
#          Comunidades &amp; Colecciones
#         </a>
#         <a class="list-group-item ds-option" href="/browse?type=dateissued">
#          Por fecha de publicación
#         </a>
#         <a class="list-group-item ds-option" href="/browse?type=author">
#          Autores
#         </a>
#         <a class="list-group-item ds-option" href="/browse?type=title">
#          Títulos
#         </a>
#         <a class="list-group-item ds-option" href="/browse?type=subject">
#          Materias
#         </a>
#         <a class="list-group-item active">
#          <span class="h5 list-group-item-heading h5">
#           Esta colección
#          </span>
#         </a>
#         <a class="list-group-item ds-option" href="/handle/20.500.12421/49/browse?type=dateissued">
#          Por fecha de publicación
#         </a>
#         <a class="list-group-item ds-option" href="/handle/20.500.12421/49/browse?type=author">
#          Autores
#         </a>
#         <a class="list-group-item ds-option" href="/handle/20.500.12421/49/browse?type=title">
#          Títulos
#         </a>
#         <a class="list-group-item ds-option" href="/handle/20.500.12421/49/browse?type=subject">
#          Materias
#         </a>
#        </div>
#        <h2 class="ds-option-set-head h6">
#         Mi cuenta
#        </h2>
#        <div class="list-group" id="aspect_viewArtifacts_Navigation_list_account">
#         <a class="list-group-item ds-option" href="/login">
#          Acceder
#         </a>
#         <a class="list-group-item ds-option" href="/register">
#          Registro
#         </a>
#        </div>
#        <div class="list-group" id="aspect_viewArtifacts_Navigation_list_context">
#        </div>
#        <div class="list-group" id="aspect_viewArtifacts_Navigation_list_administrative">
#        </div>
#        <div class="list-group" id="aspect_discovery_Navigation_list_discovery">
#        </div>
#        <h2 class="ds-option-set-head h6">
#         Estadísticas
#        </h2>
#        <div class="list-group" id="aspect_statistics_Navigation_list_statistics">
#         <a class="list-group-item ds-option" href="/handle/20.500.12421/5080/statistics">
#          Ver Estadísticas de uso
#         </a>
#        </div>
#       </div>
#      </div>
#     </div>
#    </div>
#    <div class="hidden-xs hidden-sm">
#     <footer>
#      <div class="row">
#       <hr/>
#       <div class="col-xs-7 col-sm-8">
#        <div>
#         <a href="http://www.dspace.org/" target="_blank">
#          DSpace software
#         </a>
#         copyright © 2002-2016
#         <a href="http://www.duraspace.org/" target="_blank">
#          DuraSpace
#         </a>
#        </div>
#        <div class="hidden-print">
#         <a href="/contact">
#          Contacto
#         </a>
#         |
#         <a href="/feedback">
#          Sugerencias
#         </a>
#        </div>
#       </div>
#       <div class="col-xs-5 col-sm-4 hidden-print">
#        <div class="pull-right">
#         <span class="theme-by">
#          Theme by
#         </span>
#         <br/>
#         <a href="http://atmire.com" target="_blank" title="Atmire NV">
#          <img alt="Atmire NV" src="/themes/Mirage2/images/atmire-logo-small.svg"/>
#         </a>
#        </div>
#       </div>
#      </div>
#      <a class="hidden" href="/htmlmap">
#      </a>
#      <p>
#      </p>
#     </footer>
#    </div>
#   </div>
#   <script type="text/javascript">
#    if(typeof window.publication === 'undefined'){
#                             window.publication={};
#                           };
#                         window.publication.contextPath= '';window.publication.themePath= '/themes/Mirage2/';
#   </script>
#   <script>
#    if(!window.DSpace){window.DSpace={};}window.DSpace.context_path='';window.DSpace.theme_path='/themes/Mirage2/';
#   </script>
#   <script src="/themes/Mirage2/scripts/theme.js">
#   </script>
#  </body>
# </html>

# %%
dastosr=[]

for datos in soup.find_all('tr'):
    dastosr.append(datos.text.replace('\n', ' ').strip())

# %%
dastosr
# Out:
# ['dc.contributor.advisorRobayo Avendaño, Angélica',
#  'dc.contributor.authorJaramillo Enríquez, Frank Steven',
#  'dc.date.accessioned2020-11-27T13:49:15Z',
#  'dc.date.available2020-11-27T13:49:15Z',
#  'dc.date.issued2020',
#  'dc.identifier.citationJaramillo Enríquez, F. S. (2020). Propuesta de mejora a la calidad en el proceso de recolección de datos en una firma encuestadora de Cali. Universidad Santiago de Cali.es_ES',
#  'dc.identifier.urihttps://repository.usc.edu.co/handle/20.500.12421/5079',
#  'dc.descriptionLa investigación de mercados en la actualidad, es una de las herramientas gerenciales que permite encontrar el camino al éxito de un\r proyecto, sin embargo, cumplir con los lineamientos de calidad en la fase de levantamiento de información de un estudio, es una tarea\r difícil de cumplir, por lo que una mejora continua enfocada en esta fase, requiere acompañamiento al personal que interviene en ella.\r El presente trabajo realizado desde un enfoque cualitativo, analizó el proceso de recolección de datos mientras se llevaban a cabo varios\r estudios de mercado durante el primer semestre del año 2019 en una firma encuestadora colombiana que tiene presencia en el territorio\r nacional con sede regional en Cali. Para la realización del trabajo se empleó una entrevista semi estructurada como la fuente de\r recolección de información requerida, dicho instrumento se aplicó a un grupo de encuestadores y a un coordinador de estudios de\r Mercado. Considerando el acceso a la información y la disponibilidad de encuestadores en la empresa al momento de realizar este\r estudio, se usó el muestreo no probabilístico, para tal fin se entrevistaron a seis encuestadores contratistas y a una persona encargada\r de coordinar los estudios de mercado en Cali; también se obtuvieron datos relevantes desde la observación participativa y no\r participativa en el proceso de recolección de información. Por medio de estas técnicas se logró identificar el papel que ejercen dichos\r colaboradores en la fase de recolección de datos a través de encuestas en un estudio de mercado. El análisis de información permitió\r identificar fallas en el cumplimiento de aspectos relacionados con la conducta ética, honestidad y veracidad del trabajo de campo\r realizado, aspectos fundamentales para el desarrollo de las actividades del encuestador acorde a la Norma ISO 20252 y el código\r internacional de ética ESOMAR. Finalmente, a partir de los hallazgos identificados, se propuso un plan de mejora señalando aspectos\r claves como la correcta supervisión y acompañamiento a la evaluación de capacitación y otras recomendaciones relacionadas con el\r uso de herramientas tecnológicas y supervisión directa de las primeras entrevistas con el fin de tener una interpretación más confiable\r en los resultados de las investigaciones.es_ES',
#  'dc.description.abstractThe investigations of markets is currently one of the general tools that lets us find a way to success in a project, however accomplishing\r with the rules of quality in the phase of picking information of a study is a hard task to accomplish because we continue focused on\r this phase, it requires accompaniment to the ones who interfere in it. The current task done from a qualitative focus analyzed the\r process of picking data while there were going on a variety of studies of market during the first semester of the year 2019 on a Colombian\r polling firm that has presence in the national territory with regional headquarters in Cali. For the realization of the job there was an\r interview semi structured as the source of of data collection required, such instrument was applied in a group of pollsters and a\r coordinator of studies of market. Considering the access to information and the availability of pollsters at the time of doing this study,\r non-probability sampling was used, for this purpose, six contractor pollsters were interviewed and one person in charge of coordinating\r studies of market in Cali; there was also relevant data obtained from the participative information and non participative in the process\r of data picking. With theses techniques it was possible to identify the role that such collaborators play in the phase of data picking with\r polls on the study of market. The análisis of information allowed to identify fails in the fulfillment of aspects related to the conduct of\r ethic, honesty and veracity of the task of the field done, fundamental aspects for the evolution of the activities from the pollster\r according to rule ISO 20252 and the code of international ethic ESOMAR. Finally, starting from the findings identified, there was a\r plan proposed from improvement pointing out key aspects like correct supervision and accompaniment to the evolution of training\r and other recommendations for the task of data picking on the use of technological tools and direct supervision of the first interviews,\r with the objective of having a trustworthy interpretation in the results of the investigation.es_ES',
#  'dc.formatapplication/pdf',
#  'dc.format.extent22 páginas',
#  'dc.language.isoeses_ES',
#  'dc.publisherUniversidad Santiago de Calies_ES',
#  'dc.rights.urihttps://creativecommons.org/licenses/by/4.0/',
#  'dc.subjectInvestigación De Mercadoes_ES',
#  'dc.subjectRecolección De Informaciónes_ES',
#  'dc.subjectCalidades_ES',
#  'dc.subjectEncuestadores_ES',
#  'dc.titlePropuesta de mejora a la calidad en el proceso de recolección de datos en una firma encuestadora de Cali.es_ES',
#  'dc.typeThesises_ES',
#  'dc.publisher.facultyFacultad de Ingeniería',
#  'dc.pubplace.cityCali',
#  'dc.rights.accesoAcceso Abierto',
#  'dc.rights.ccReconocimiento 4.0 Internacional (CC BY 4.0)',
#  'dc.source.repositoryRepositorio Institucional USC',
#  'dc.source.institutionUniversidad Santiago de Cali',
#  'dc.type.spaArticulo',
#  'dc.creator.degreeTrabajo de grado para optar al título de Ingeniero Industrial',
#  'dc.publisher.programIngeniería Industrial',
#  'dc.pubplace.stateValle del Cauca',
#  'dc.subject.keywordMarket Research',
#  'dc.subject.keywordInformation Collection',
#  'dc.subject.keywordSurveys',
#  'dc.subject.keywordQuality',
#  'dc.subject.keywordSurveyors']

# %%
advisor=dastosr[0].replace('dc.contributor.advisor', '').strip()

datostexto=[]
for valor in dastosr:
        if valor.startswith('dc.subject.keyword'):
            datostexto.append(valor[18:])

# %%
advisor
# Out:
# 'Salazar Ramos, Andrés Felipe'

# %%
datostextoesp=[]
for valoresp in dastosr:
        if valoresp.startswith('dc.subject'):
            datostextoesp.append(valoresp[10:])

# %%
datostextoesp_=[]
for valoresp_ in datostextoesp:
        if not valoresp_.startswith('.keyword'):
            datostextoesp_.append(valoresp_.replace('es_ES', '').strip())

# %%
datostextoesp_
# Out:
# ['Simulación Y Estimación Del Tiempo',
#  'Lanzamiento De Nuevos Productos',
#  'Incertidumbre',
#  'Gerencia De Proyectos']

# %%
#construcción de un diccionario
resultados = datostextoesp_
count = advisor
d = {} 
for i in resultados:
    d[i] = advisor

# %%
d
# Out:
# {'Simulación Y Estimación Del Tiempo': 'Salazar Ramos, Andrés Felipe',
#  'Lanzamiento De Nuevos Productos': 'Salazar Ramos, Andrés Felipe',
#  'Incertidumbre': 'Salazar Ramos, Andrés Felipe',
#  'Gerencia De Proyectos': 'Salazar Ramos, Andrés Felipe'}

# %%
import pandas as pd

dataframe=pd.Series(d).to_frame('Advisor').reset_index()

# %%
dataframe=dataframe.rename(columns={'index':'Keyword'})

# %%
dataframe
# Out:
#                               Keyword                       Advisor
# 0  Simulación Y Estimación Del Tiempo  Salazar Ramos, Andrés Felipe
# 1     Lanzamiento De Nuevos Productos  Salazar Ramos, Andrés Felipe
# 2                       Incertidumbre  Salazar Ramos, Andrés Felipe
# 3               Gerencia De Proyectos  Salazar Ramos, Andrés Felipe

# %%
dataframe = dataframe[["Advisor",'Keyword']]

# %%
dataframe
# Out:
#                         Advisor                             Keyword
# 0  Salazar Ramos, Andrés Felipe  Simulación Y Estimación Del Tiempo
# 1  Salazar Ramos, Andrés Felipe     Lanzamiento De Nuevos Productos
# 2  Salazar Ramos, Andrés Felipe                       Incertidumbre
# 3  Salazar Ramos, Andrés Felipe               Gerencia De Proyectos

# %%
dataframe.columns
# Out:
# Index(['Advisor', 'Keyword'], dtype='object')

# %%
dataframe
# Out:
#                         Advisor                             Keyword
# 0  Salazar Ramos, Andrés Felipe  Simulación Y Estimación Del Tiempo
# 1  Salazar Ramos, Andrés Felipe     Lanzamiento De Nuevos Productos
# 2  Salazar Ramos, Andrés Felipe                       Incertidumbre
# 3  Salazar Ramos, Andrés Felipe               Gerencia De Proyectos

# %%
d
# Out:
# {'Simulación Y Estimación Del Tiempo': 'Salazar Ramos, Andrés Felipe',
#  'Lanzamiento De Nuevos Productos': 'Salazar Ramos, Andrés Felipe',
#  'Incertidumbre': 'Salazar Ramos, Andrés Felipe',
#  'Gerencia De Proyectos': 'Salazar Ramos, Andrés Felipe'}

# %%
d
# Out:
# {'Simulación Y Estimación Del Tiempo': 'Salazar Ramos, Andrés Felipe',
#  'Lanzamiento De Nuevos Productos': 'Salazar Ramos, Andrés Felipe',
#  'Incertidumbre': 'Salazar Ramos, Andrés Felipe',
#  'Gerencia De Proyectos': 'Salazar Ramos, Andrés Felipe'}

# %%
#Uso de librería para considerar la similitud entre palabras claves
from difflib import SequenceMatcher

def similar(a, b):
    return SequenceMatcher(None, a, b).ratio()

# %%
similar("Facility Scheduling","Production Planning")
# Out:
# 0.3157894736842105

# %%
datostextoesp
# Out:
# ['Simulación Y Estimación Del Tiempoes_ES',
#  'Lanzamiento De Nuevos Productoses_ES',
#  'Incertidumbrees_ES',
#  'Gerencia De Proyectoses_ES',
#  '.keywordSimulation And Time Modification',
#  '.keywordLaunch Of New Products',
#  '.keywordUncertainty',
#  '.keywordProject Management']

# %%
datostexto
# Out:
# ['Simulation And Time Modification',
#  'Launch Of New Products',
#  'Uncertainty',
#  'Project Management']

# %%
dastosr
# Out:
# ['dc.contributor.advisorSalazar Ramos, Andrés Felipe',
#  'dc.contributor.authorMena Ibargüen, Gina Alexandra',
#  'dc.date.accessioned2020-11-27T14:18:17Z',
#  'dc.date.available2020-11-27T14:18:17Z',
#  'dc.date.issued2020',
#  'dc.identifier.citationMena Ibargüen, G. A. (2020). Simulación y estimación del tiempo esperado en la gestión de un proyecto en una empresa de alimentos. Universidad Santiago de Cali.es_ES',
#  'dc.identifier.urihttps://repository.usc.edu.co/handle/20.500.12421/5080',
#  'dc.descriptionEn este artículo se presenta la propuesta de simulación y estimación del tiempo esperado en la gestión de un proyecto para el\r lanzamiento de nuevos productos, en una empresa de alimentos fabricante y comerciante de chips de maíz, papitas fritas y otros\r aperitivos, realizando la identificación, atención de los posibles riesgos dentro de la gestión del proyecto con el fin de\r implementar un plan de mejoramiento que permita mitigar, controlar y dar tratamiento a aquellos riesgos que generen un\r impacto negativo y puedan impedir el cumplimiento de los tiempos establecidos para cada actividad del proyecto. Para dar\r cumplimiento con los objetivos propuestos se utilizó la metodología de Simulación Montecarlo, buscando calcular probabilidades\r con secuencias de números aleatorios.es_ES',
#  'dc.description.abstractThe article presents the proposed simulation and modification of the expected time in the management of a project for the launch of\r new products, in a food company that manufactures and markets corn chips, French fries and other snacks, identify, the possible\r risks within the project management in order to implement an improvement plan that allows mitigating, controlling and treating those\r risks that generate a negative impact and can avoid meeting the times established for each project activity. To meet the proposed\r objectives, the Monte Carlo simulation methodology was used, seeking to calculate the challenges with sequences of random\r numbers.es_ES',
#  'dc.formatapplication/pdf',
#  'dc.format.extent18 páginas',
#  'dc.language.isoeses_ES',
#  'dc.publisherUniversidad Santiago de Calies_ES',
#  'dc.rights.urihttps://creativecommons.org/licenses/by/4.0/',
#  'dc.subjectSimulación Y Estimación Del Tiempoes_ES',
#  'dc.subjectLanzamiento De Nuevos Productoses_ES',
#  'dc.subjectIncertidumbrees_ES',
#  'dc.subjectGerencia De Proyectoses_ES',
#  'dc.titleSimulación y estimación del tiempo esperado en la gestión de un proyecto en una empresa de alimentos.es_ES',
#  'dc.typeThesises_ES',
#  'dc.publisher.facultyFacultad de Ingeniería',
#  'dc.pubplace.cityCali',
#  'dc.rights.accesoAcceso Abierto',
#  'dc.rights.ccReconocimiento 4.0 Internacional (CC BY 4.0)',
#  'dc.source.repositoryRepositorio Institucional USC',
#  'dc.source.institutionUniversidad Santiago de Cali',
#  'dc.type.spaArticulo',
#  'dc.creator.degreeTrabajo de grado para optar al título de Ingeniero Industrial',
#  'dc.publisher.programIngeniería Industrial',
#  'dc.pubplace.stateValle del Cauca',
#  'dc.subject.keywordSimulation And Time Modification',
#  'dc.subject.keywordLaunch Of New Products',
#  'dc.subject.keywordUncertainty',
#  'dc.subject.keywordProject Management']

# %%
for valor in dastosr:

# %%
table_data=[]
for tr in soup.find_all('tr'):
    t_row={}
    for td in tr.find_all('td'):
        t_row=td.text.replace('\n', '').strip()
    table_data.append(t_row)

# %%
table_data
# Out:
# ['',
#  '',
#  '',
#  '',
#  '',
#  'es_ES',
#  '',
#  'es_ES',
#  'es_ES',
#  '',
#  '',
#  'es_ES',
#  'es_ES',
#  '',
#  'es_ES',
#  'es_ES',
#  'es_ES',
#  'es_ES',
#  'es_ES',
#  'es_ES',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '']

# %%
data = {}
for table, heading in zip(find_all("table"), headings):
    # Get headers of table i.e., Rank, Country, GDP.
    t_headers = []
    for th in table.find_all("th"):
        # remove any newlines and extra spaces from left and right
        t_headers.append(th.text.replace('\n', ' ').strip())
    # Get all the rows of table
    table_data = []
    for tr in table.tbody.find_all("tr"): # find all tr's from table's tbody
        t_row = {}
        # Each table row is stored in the form of
        # t_row = {'Rank': '', 'Country/Territory': '', 'GDP(US$million)': ''}

        # find all td's(3) in tr and zip it with t_header
        for td, th in zip(tr.find_all("td"), t_headers): 
            t_row[th] = td.text.replace('\n', '').strip()
        table_data.append(t_row)

    # Put the data for the table with his heading.
    data[heading] = table_data

print(data)

# %%
elementos=BeautifulSoup(page.content,'html.parser').text

# %%
elementos.title
# Out:
# <function str.title()>

# %%
sopa=BeautifulSoup(html_content, "lxml")

# %%
resultados=elementos.find_all('tr')

# %%
resultados
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-31-fe96ba2b47be> in <module>
# ----> 1 resultados.text
#
# ~\anaconda3\lib\site-packages\bs4\element.py in __getattr__(self, key)
#    2158     def __getattr__(self, key):
#    2159         """Raise a helpful exception to explain a common code fix."""
# -> 2160         raise AttributeError(
#    2161             "ResultSet object has no attribute '%s'. You're probably treating a list of elements like a single element. Did you call find_all() when you meant to call find()?" % key
#    2162         )
#
# AttributeError: ResultSet object has no attribute 'text'. You're probably treating a list of elements like a single element. Did you call find_all() when you meant to call find()?
